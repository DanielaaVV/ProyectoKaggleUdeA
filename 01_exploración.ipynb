# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaaVV/ProyectoKaggleUdeA/blob/main/01_exploraci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **UDEA/ai4eng 20251 - Pruebas Saber Pro Colombia ***

# %% [markdown]
# - Daniela Vela Velasquez - 1007241907 - Ingeniería de sistemas
# - Jesus Estiven Torres Quintero - 1000759253 - Ingeniería de sistemas
# - Juan Pablo Ramos Vélez - 1193518347 - Ingeniería de sistemas

# %% [markdown]
# #Cargamos los datos de `train.csv` y se instala rlxutils

# %%
import pandas as pd
import numpy as np

z = pd.read_csv("train.csv")
print ("Se cargaron los datos correctamente", z.shape)
# Out:
# Se cargaron los datos correctamente (692500, 21)

# %%
# !pip install rlxutils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rlxutils: filename=rlxutils-0.1.10-py3-none-any.whl size=11100 sha256=417b95baa4a171d01bae7d637ea179a7d71f727b2fbdf8dc0c0707da87a5b567
#   Stored in directory: /root/.cache/pip/wheels/1d/99/c0/f49a3db4e38f121da6a422c352a7ff70baf2cc21c25b851a6c
# Successfully built rlxutils
# ...

# %% [markdown]
# **Ingresamos un método de exploración para mirar los archivos en cabeza y cola del documento**

# %%
z.head(10)
# Out:
#        ID  PERIODO                  ESTU_PRGM_ACADEMICO  \
# 0  904256  20212.0                           ENFERMERIA
# 1  645256  20212.0                              DERECHO
# 2  308367  20203.0                MERCADEO Y PUBLICIDAD
# 3  470353  20195.0           ADMINISTRACION DE EMPRESAS
# 4  989032  20212.0                           PSICOLOGIA
# 5  659872  20203.0                 MEDICINA VETERINARIA
# 6   47159  20183.0                  INGENIERIA MECANICA
# 7   11829  20183.0  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 8  257869  20212.0                INGENIERIA INDUSTRIAL
# 9  465511  20183.0           ADMINISTRACION DE EMPRESAS
#
#   ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0                 BOGOTÁ  Entre 5.5 millones y menos de 7 millones
# 1              ATLANTICO  Entre 2.5 millones y menos de 4 millones
# 2                 BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 3              SANTANDER  Entre 4 millones y menos de 5.5 millones
# ...

# %%
z.tail(10)
# Out:
#                                                        ID  PERIODO  \
# 692490                                             403947  20195.0
# 692491                                             157529  20212.0
# 692492                                             584597  20183.0
# 692493                                             725949  20203.0
# 692494  649690,20212,"LICENCIATURA EN EDUCACION BASICA...      NaN
# 692495                                              25096  20195.0
# 692496                                             754213  20212.0
# 692497                                             504185  20183.0
# 692498                                             986620  20195.0
# 692499                                             933374  20195.0
#
#                                    ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 692490                                      PSICOLOGIA                BOLIVAR
# ...

# %% [markdown]
# **Definimos un espacio de muestreo con sólo 4 columnas**

# %%
z = z[['ESTU_PRGM_DEPARTAMENTO','FAMI_ESTRATOVIVIENDA', 'ESTU_VALORMATRICULAUNIVERSIDAD', 'RENDIMIENTO_GLOBAL']]
z.head(10)
# Out:
#   ESTU_PRGM_DEPARTAMENTO FAMI_ESTRATOVIVIENDA  \
# 0                 BOGOTÁ            Estrato 3
# 1              ATLANTICO            Estrato 3
# 2                 BOGOTÁ            Estrato 3
# 3              SANTANDER            Estrato 4
# 4              ANTIOQUIA            Estrato 3
# 5              ANTIOQUIA            Estrato 5
# 6                  HUILA            Estrato 2
# 7                 BOGOTÁ            Estrato 2
# 8              ATLANTICO            Estrato 1
# 9              ANTIOQUIA            Estrato 5
#
#              ESTU_VALORMATRICULAUNIVERSIDAD RENDIMIENTO_GLOBAL
# 0  Entre 5.5 millones y menos de 7 millones         medio-alto
# 1  Entre 2.5 millones y menos de 4 millones               bajo
# 2  Entre 2.5 millones y menos de 4 millones               bajo
# 3  Entre 4 millones y menos de 5.5 millones               alto
# 4  Entre 2.5 millones y menos de 4 millones         medio-bajo
# 5                         Más de 7 millones         medio-alto
# ...

# %% [markdown]
# **Analizamos los datos completos con gráficas de datos**

# %%
z.FAMI_ESTRATOVIVIENDA.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
z.FAMI_ESTRATOVIVIENDA.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='FAMI_ESTRATOVIVIENDA'>

# %% [markdown]
# **Por último comparamos el rendimiento global junto a estrato de vivienda y estrato de vivienda en 4 Departamentos**

# %%
from rlxutils import subplots
import matplotlib.pyplot as plt

c = sorted(z.FAMI_ESTRATOVIVIENDA.value_counts().index)
for ax,ci in subplots(c, n_cols=4, usizex=4):
    zc = z[z.FAMI_ESTRATOVIVIENDA==ci]
    zc.RENDIMIENTO_GLOBAL.value_counts()[['bajo', 'medio-bajo', 'medio-alto', 'alto']].plot(kind='bar')
    plt.title(ci)

# %%
c = sorted(z.FAMI_ESTRATOVIVIENDA.value_counts().index)
for ax,ci in subplots(c, n_cols=4, usizex=4):
    zc = z[z.FAMI_ESTRATOVIVIENDA==ci]
    zc.	ESTU_PRGM_DEPARTAMENTO.value_counts()[['SANTANDER', 'ANTIOQUIA', 'ATLANTICO', 'LA GUAJIRA']].plot(kind='bar')
    plt.title(ci)
